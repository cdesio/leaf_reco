# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.image import imread
import os

# %%
data_dir = "/storage/yw18581/data/"

# %%
train_val_test_dir = os.path.join(data_dir,"train_validation_test")

# %%
/storage/yw18581/data/train_validation_test/Xy_3mm.npz"

# %%
data_3mm = np.load(os.path.join(train_val_test_dir,"Xy_3mm.npz"))["y"]

# %%
idx = np.arange(50,349,50)

# %%
imgs = []
for i in idx:
    img = data_3mm[i-1][...,0]
    imgs.append(img)
    plt.imshow(img, cmap='gray')
    plt.show()

# %%
plt.imshow(imgs[0]-imgs[1], cmap='gray')
plt.show()

# %%
for k, j in enumerate(imgs):
    if k+1 < len(imgs):
        plt.imshow(imgs[k+1]-imgs[k], cmap='gray')
        plt.show()
