# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import os

# %%
data_dir = '/storage/yw18581/data/'
data_folder = os.path.join(data_dir, 'train_validation_test')
clean_dir = os.path.join(data_folder, 'clean_300_june')

# %%
predicted_list = sorted([i for i in sorted(os.listdir(clean_dir)) if "predicted" in str(i)])

# %%
predicted_list
# Out:
# ['Xy_10mm_clean_300_june_predicted_UNet_retrained_1600.npz',
#  'Xy_15mm_clean_300_june_predicted_UNet_retrained_1600.npz',
#  'Xy_1mm_clean_300_june_predicted_UNet_retrained_1600.npz',
#  'Xy_20mm_clean_300_june_predicted_UNet_retrained_1600.npz',
#  'Xy_25mm_clean_300_june_predicted_UNet_retrained_1600.npz',
#  'Xy_2mm_clean_300_june_predicted_UNet_retrained_1600.npz',
#  'Xy_30mm_clean_300_june_predicted_UNet_retrained_1600.npz',
#  'Xy_35mm_clean_300_june_predicted_UNet_retrained_1600.npz',
#  'Xy_3mm_clean_300_june_predicted_UNet_retrained_1600.npz',
#  'Xy_4mm_clean_300_june_predicted_UNet_retrained_1600.npz',
#  'Xy_clean_300_june_predicted_UNet_retrained_1600.npz']

# %%
for fname in predicted_list:
    Xy = np.load(os.path.join(clean_dir, fname))
    for i in range(10):
        plt.imshow(Xy["y"][i], cmap='gray')
        plt.show()

# %%
Xy = np.load(os.path.join(clean_dir, predicted_list[0]))

# %%
y = Xy["y"]

# %%
y[0].shape
# Out:
# (1400, 1400)
