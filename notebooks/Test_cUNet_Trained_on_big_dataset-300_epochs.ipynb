# %%
import sys, os
import torch
import torch.nn as nn
import numpy as np
from torchvision import transforms
from tqdm.notebook import tqdm, trange
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt

# %%
from sklearn.metrics import mean_squared_error

# %%
sys.path.append("../")

# %%
from Transformers import ChannelsFirst, ToTensor, Cut, Rescale, splitter_train_val_test

# %%
from DataSets import UNetDatasetFromFolders

# %%
from cUNet_pytorch_pooling import cUNet, dice_loss

# %%
DATA_DIR_DEEPTHOUGHT="/storage/yw18581/data"
data_dir = DATA_DIR_DEEPTHOUGHT

# %%
model_name = "../model/trained_cUNet_pytorch_regression_complete_dataset_300epochs_coeff_mask0.75_validation.pkl"

# %%
model_inference = cUNet(out_size=1)

# %%
model_inference.load_state_dict(torch.load(model_name))
# Out:
# <All keys matched successfully>

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
root_folder = os.path.join(data_dir, "dataset")

# %%
composed = transforms.Compose([Cut(), Rescale(.25), ChannelsFirst(), ToTensor()])

# %%
complete_dataset = UNetDatasetFromFolders(root_folder, transform=composed)

# %%
data_loaders, data_lengths = splitter_train_val_test(complete_dataset,
                                                    validation_split=0.2,
                                                    test_split=0.2,
                                                    batch=16,
                                                    workers=4)

# %%
data_lengths
# Out:
# {'train': 5717, 'val': 1429, 'test': 1786}

# %%
model_inference.eval()
model_inference.to(device);

# %%
for i, batch in enumerate(data_loaders['test']):

    true_images, true_masks, true_dists = batch['image'], batch['mask'], batch['dist']
    pred_masks, pred_dists = model_inference(true_images.float().to(device))
    print("batch {}".format(i+1))
    for j, (img, tr_msk, tr_dist, pr_msk, pr_dist) in enumerate(zip(true_images,
                                                 true_masks, 
                                                 true_dists.cpu().detach().numpy(),
                                                 pred_masks.cpu().detach().numpy(), 
                                                 pred_dists.cpu().detach().numpy())):
    
        true_dist = tr_dist
        pred_dist = pr_dist
        print("{}: true_dist: {}, pred_dist: {}".format(j+1, true_dist, pred_dist))
        
        f = plt.figure(figsize=(10,5))
        f.add_subplot(1,3, 1)
        plt.imshow(img[0,...], cmap='gray')
        f.add_subplot(1,3, 2)
        plt.imshow(tr_msk[0,...], cmap='gray')
        f.add_subplot(1,3, 3)
        plt.imshow(pr_msk[0,...], cmap='gray')
        plt.show(block=True)
        
    if i==1:
        break
# Out:
# batch 1
# 1: true_dist: 3, pred_dist: [2.984858]
# 2: true_dist: 15, pred_dist: [14.999432]
# 3: true_dist: 30, pred_dist: [30.01183]
# 4: true_dist: 10, pred_dist: [10.005111]
# 5: true_dist: 10, pred_dist: [10.001828]
# 6: true_dist: 35, pred_dist: [35.002808]
# 7: true_dist: 15, pred_dist: [15.010103]
# 8: true_dist: 4, pred_dist: [3.9987807]
# 9: true_dist: 1, pred_dist: [0.99831724]
# 10: true_dist: 30, pred_dist: [30.016499]
# 11: true_dist: 30, pred_dist: [29.998793]
# 12: true_dist: 25, pred_dist: [25.02011]
# 13: true_dist: 10, pred_dist: [9.990312]
# 14: true_dist: 20, pred_dist: [20.003048]
# 15: true_dist: 2, pred_dist: [2.0039923]
# 16: true_dist: 10, pred_dist: [9.99343]
# batch 2
# 1: true_dist: 2, pred_dist: [2.0082211]
# 2: true_dist: 3, pred_dist: [3.006899]
# 3: true_dist: 3, pred_dist: [3.0122128]
# 4: true_dist: 20, pred_dist: [20.00789]
# 5: true_dist: 4, pred_dist: [3.9981341]
# 6: true_dist: 10, pred_dist: [9.999911]
# 7: true_dist: 1, pred_dist: [1.0037405]
# 8: true_dist: 20, pred_dist: [20.010576]
# 9: true_dist: 1, pred_dist: [1.0032026]
# 10: true_dist: 20, pred_dist: [20.001514]
# 11: true_dist: 1, pred_dist: [0.99577457]
# 12: true_dist: 4, pred_dist: [4.01444]
# 13: true_dist: 1, pred_dist: [0.98901814]
# 14: true_dist: 30, pred_dist: [30.016981]
# 15: true_dist: 15, pred_dist: [14.998087]
# 16: true_dist: 1, pred_dist: [1.0037878]

# %%
batch_size=16

# %%
y_true = []
y_pred = []

for i, batch in tqdm(enumerate(data_loaders['test']), total = data_lengths['test']//batch_size, desc = "Mini Batch"):
    true_images, true_dists = batch['image'], batch['dist']
    _, pred_dists = model_inference(true_images.float().to(device))
#    print("batch {}".format(i + 1))
    for j, (img, tr_dist, pr_dist) in enumerate(zip(true_images,
                                                true_dists.cpu().detach().numpy(),
                                                pred_dists.cpu().detach().numpy())):
        true_dist = tr_dist
        pred_dist = pr_dist
        y_true.append(true_dist)
        y_pred.append(pred_dist)
# Out:
# HBox(children=(IntProgress(value=0, description='Mini Batch', max=111, style=ProgressStyle(description_width='…

# %%
y_pred = np.asarray(y_pred).ravel()
y_true = np.asarray(y_true)

print("mse: {}".format(mean_squared_error(y_true, y_pred)))
# Out:
# mse: 0.0001116419926400168

# %%
def get_idx(arr, key):
    return np.where(arr==key)[0]

# %%
def idx_mse(dist, true_arr = y_true, preds_arr = y_pred):
    idx = np.where(true_arr==dist)[0]
    mse = mean_squared_error(true_arr[idx], preds_arr[idx])
    print(dist, mse)
    return idx, mse

# %%
idx_1, mse_1 = idx_mse(1)
idx_2, mse_2 = idx_mse(2)
idx_3, mse_3 = idx_mse(3)
idx_4, mse_4 = idx_mse(4)
idx_10, mse_10 = idx_mse(10)
idx_15, mse_15 = idx_mse(15)
idx_20, mse_20 = idx_mse(20)
idx_25, mse_25 = idx_mse(25)
idx_30, mse_30 = idx_mse(30)
idx_35, mse_35 = idx_mse(35)
# Out:
# 1 4.094941069442872e-05
# 2 0.00015397875796866186
# 3 0.00017336015633564916
# 4 0.00013184192435095778
# 10 4.404253209055157e-05
# 15 4.053872608927351e-05
# 20 9.5335788766656e-05
# 25 0.00013716263715145437
# 30 0.00015368301883534826
# 35 0.00015220613911778354

# %%
distances = [1,2,3,4,10,15,20,25,30,35]

# %%
errors = [idx_mse(i)[1] for i in distances]
# Out:
# 1 4.094941069442872e-05
# 2 0.00015397875796866186
# 3 0.00017336015633564916
# 4 0.00013184192435095778
# 10 4.404253209055157e-05
# 15 4.053872608927351e-05
# 20 9.5335788766656e-05
# 25 0.00013716263715145437
# 30 0.00015368301883534826
# 35 0.00015220613911778354

# %%
plt.plot(distances, errors)
plt.ylim((0,0.05))
# Out:
# (0, 0.05)

# %%
np.savez_compressed("Predicted_ALL_out_model_trained_on_ALLDATA_300_epochs.npz", true=y_true, pred = y_pred)
