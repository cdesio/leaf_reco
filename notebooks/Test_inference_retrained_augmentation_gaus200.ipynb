# %%
import sys, os
import matplotlib.pyplot as plt
sys.path.append('../')
from sklearn.metrics import mean_squared_error
import re
import numpy as np

# %%
from core.models import rUNet
from core.utils.inference import inference_phase_rUNet_plot_notebook
from core.utils.data import define_dataset, select_dist

# %%
from core.utils.data.transformers import ChannelsFirst, Rescale, ToTensor, Crop, GaussianNoise, RandomCrop, Swap, \
        FlipUD, FlipLR

# %%
from functools import partial

# %%
import torch

# %%
# %matplotlib inline

# %%
regex = re.compile(r'\d+')

# %%
saved_models = '/storage/yw18581/src/leaf_reco/saved_models/trained_6positions_multi_loss_augmentation_gaus200'

# %%
root_path = partial(os.path.join, saved_models)

# %%
data_folder = ('/storage/yw18581/data/dataset/')

# %%
model_names = os.listdir(saved_models)

# %%
def get_fnames(coeff, prefix='Trained'):
    idx_coef = 6 if prefix=='Trained' else 4
    idx_epoch = 5 if prefix =='Trained' else 3
    f_list = []
    epochs = []
    for fname in model_names:
        if fname.startswith(prefix):
            if regex.findall(fname.split("_")[idx_coef])[1]==str(coeff):
                epoch = int(regex.findall(fname.split("_")[idx_epoch])[0]) 
                epochs.append(epoch)
                if int(regex.findall(fname.split("_")[idx_epoch])[0])==epoch:
                    f_list.append(fname)
    
    return np.array(f_list)[np.argsort(epochs)], np.sort(epochs)

# %% [markdown]
# ---

# %% [markdown]
# ### Inference on test unseen data

# %%
training_dist = [2,4,10,20,25,35]
unseen_dist = [1,3,15,30]
selected_distances = select_dist(data_folder, unseen_dist)

# %%
base_transformers = [Crop(row_slice=slice(0,1400), col_slice=slice(1000,None)),
                           Rescale(scale=0.25), ChannelsFirst(),ToTensor()]

# %%
base_transfofrmers_2 = [RandomCrop(p=1), Swap(p=0.7), FlipLR(p=0.7), FlipUD(p=0.7),
                        Rescale(0.25), ChannelsFirst(),ToTensor()]

# %%
data_loaders, data_length = define_dataset(root_folder=data_folder, 
                                           base_transformers=base_transformers,
                                           train_transformers=base_transformers,
                                           batch_size=4, include_list=selected_distances,
                                            alldata=True, multi_processing=4)

# %%
def predict_coef_epoch(coeff, epoch):
    filelist, epochs = get_fnames(coeff)
    model_fname = filelist[int(np.argwhere(epochs==epoch)[0])]
    print(model_fname)
    torch.cuda.empty_cache()
    model = rUNet(out_size=1)
    checkpoint = torch.load(root_path(model_fname))['model_state_dict']
    #print(checkpoint)
    model.load_state_dict(checkpoint)
    
    print('Checkpoint loaded')
    inference_phase_rUNet_plot_notebook(model, data_loaders, data_length,
                                       batch_size=4, stop=1, test=False)

    return

# %%
predict_coef_epoch(4, 500)
# Out:
# Trained_rUNet_pytorch_6positions_dataset_500epochs_0.4coeff_mask.pkl
# Checkpoint loaded
# HBox(children=(IntProgress(value=0, description='Batch', max=883, style=ProgressStyle(description_width='initi…
# batch 1
# 1: true_dist: 15, pred_dist: [15.192448]
# 2: true_dist: 15, pred_dist: [15.044762]
# 3: true_dist: 15, pred_dist: [14.96214]
# 4: true_dist: 15, pred_dist: [14.868667]
# batch 2
# 1: true_dist: 15, pred_dist: [15.060258]
# 2: true_dist: 15, pred_dist: [15.146748]
# 3: true_dist: 15, pred_dist: [14.840312]
# 4: true_dist: 15, pred_dist: [14.886612]

# %%
for epoch in np.arange(110, 160, 10):
    predict_coef_epoch(4, epoch)
# Out:
# Trained_rUNet_pytorch_6positions_dataset_110epochs_0.4coeff_mask.pkl
# Checkpoint loaded
# HBox(children=(IntProgress(value=0, description='Batch', max=883, style=ProgressStyle(description_width='initi…
# batch 1
# 1: true_dist: 15, pred_dist: [9.261053]
# 2: true_dist: 15, pred_dist: [12.225747]
# 3: true_dist: 15, pred_dist: [10.928608]
# 4: true_dist: 15, pred_dist: [9.744109]
# batch 2
# 1: true_dist: 15, pred_dist: [10.108637]
# 2: true_dist: 15, pred_dist: [10.775308]
# 3: true_dist: 15, pred_dist: [12.039327]
# 4: true_dist: 15, pred_dist: [10.286826]
# Trained_rUNet_pytorch_6positions_dataset_120epochs_0.4coeff_mask.pkl
# Checkpoint loaded
# HBox(children=(IntProgress(value=0, description='Batch', max=883, style=ProgressStyle(description_width='initi…
# batch 1
# 1: true_dist: 15, pred_dist: [11.848047]
# 2: true_dist: 15, pred_dist: [13.49547]
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fa3c820a048>
# Traceback (most recent call last):
#   File "/storage/yw18581/src/env_dir/mlearning/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 926, in __del__
#     self._shutdown_workers()
#   File "/storage/yw18581/src/env_dir/mlearning/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 906, in _shutdown_workers
#     w.join()
#   File "/storage/yw18581/src/env_dir/mlearning/lib/python3.7/multiprocessing/process.py", line 140, in join
#     res = self._popen.wait(timeout)
#   File "/storage/yw18581/src/env_dir/mlearning/lib/python3.7/multiprocessing/popen_fork.py", line 48, in wait
#     return self.poll(os.WNOHANG if timeout == 0.0 else 0)
#   File "/storage/yw18581/src/env_dir/mlearning/lib/python3.7/multiprocessing/popen_fork.py", line 28, in poll
#     pid, sts = os.waitpid(self.pid, flag)
# KeyboardInterrupt:
# 3: true_dist: 15, pred_dist: [12.443066]
# 4: true_dist: 15, pred_dist: [11.925163]
# batch 2
# 1: true_dist: 15, pred_dist: [12.845611]
# 2: true_dist: 15, pred_dist: [12.61582]
# 3: true_dist: 15, pred_dist: [12.858613]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-43a56d2386f9> in <module>
#       1 for epoch in np.arange(110, 160, 10):
# ----> 2     predict_coef_epoch(4, epoch)
#
# <ipython-input-17-9d3f68a4bab8> in predict_coef_epoch(coeff, epoch)
#      11     print('Checkpoint loaded')
#      12     inference_phase_rUNet_plot_notebook(model, data_loaders, data_length,
# ---> 13                                        batch_size=4, stop=1, test=False)
#      14
#      15     return
#
# /scratch/yw18581/src/leaf_reco/core/utils/inference.py in inference_phase_rUNet_plot_notebook(model, data_loaders, data_lengths, batch_size, stop, dev, test)
#     104                 f.add_subplot(1, 3, 3)
#     105                 plt.imshow(pr_msk[0, ...], cmap='gray')
# --> 106                 plt.show(block=True)
#     107
#     108             if i == stop:
#
# /storage/yw18581/src/env_dir/mlearning/lib/python3.7/site-packages/matplotlib/pyplot.py in show(*args, **kw)
#     267     """
#     268     global _show
# --> 269     return _show(*args, **kw)
#     270
#     271
#
# /storage/yw18581/src/env_dir/mlearning/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ---> 39                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      40             )
#      41     finally:
#
# /storage/yw18581/src/env_dir/mlearning/lib/python3.7/site-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     311             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     312         else:
# --> 313             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     314             if not format_dict:
#     315                 # nothing to display (e.g. _ipython_display_ took over)
#
# /storage/yw18581/src/env_dir/mlearning/lib/python3.7/site-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# </storage/yw18581/src/env_dir/mlearning/lib/python3.7/site-packages/decorator.py:decorator-gen-9> in __call__(self, obj)
#
# /storage/yw18581/src/env_dir/mlearning/lib/python3.7/site-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# /storage/yw18581/src/env_dir/mlearning/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /storage/yw18581/src/env_dir/mlearning/lib/python3.7/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     242
#     243     if 'png' in formats:
# --> 244         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     245     if 'retina' in formats or 'png2x' in formats:
#     246         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# /storage/yw18581/src/env_dir/mlearning/lib/python3.7/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     126
#     127     bytes_io = BytesIO()
# --> 128     fig.canvas.print_figure(bytes_io, **kw)
#     129     data = bytes_io.getvalue()
#     130     if fmt == 'svg':
#
# /storage/yw18581/src/env_dir/mlearning/lib/python3.7/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2061                         orientation=orientation,
#    2062                         dryrun=True,
# -> 2063                         **kwargs)
#    2064                     renderer = self.figure._cachedRenderer
#    2065                     bbox_artists = kwargs.pop("bbox_extra_artists", None)
#
# /storage/yw18581/src/env_dir/mlearning/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     530                     cbook.open_file_cm(filename_or_obj, "wb") as fh:
#     531                 _png.write_png(renderer._renderer, fh,
# --> 532                                self.figure.dpi, metadata=metadata)
#     533
#     534     def print_to_buffer(self):
#
# KeyboardInterrupt:

# %% [markdown]
# ### Test on multi-leaf dataset

# %%
data_folder_multi = '/storage/yw18581/data/v2_avg/top_right/'

# %%
excluded = []

# %%
data_loaders, data_length = define_dataset(root_folder=data_folder_multi, base_transformers=base_transformers,
                                           train_transformers=base_transformers,
                                           batch_size=4, excluded_list=excluded,
                                            alldata=True, multi_processing=4, load_mask=False)

# %%
def inference_phase_rUNet_plot_notebook(model, data_loaders, data_lengths, batch_size, stop=1, dev=0, test=True):
    from tqdm.notebook import tqdm
    import matplotlib.pyplot as plt

    device = torch.device("cuda:{}".format(dev) if torch.cuda.is_available() else "cpu")
    # model = cUNet(out_size=1)

    # model.load_state_dict(torch.load(model_name))
    model.eval()
    model.to(device);
    for i, batch in tqdm(enumerate(data_loaders), total=data_lengths // batch_size,
                     desc="Batch"):

        true_images = batch["image"]
        pred_masks, pred_dists = model(true_images.float().to(device))
        print("batch {}".format(i + 1))
        for j, (img, pr_msk, pr_dist) in enumerate(zip(true_images,
                                                                        pred_masks.cpu().detach().numpy(),
                                                                        pred_dists.cpu().detach().numpy())):
            print("{}: pred_dist: {}".format(j + 1, pr_dist))

            f = plt.figure(figsize=(10, 5))
            f.add_subplot(1, 2, 1)
            plt.imshow(img[0, ...], cmap='gray')
            f.add_subplot(1, 2, 2)
            plt.imshow(pr_msk[0, ...], cmap='gray')
            plt.show(block=True)

        if i == stop:
            break

# %%
predict_coef_epoch(4,180)
# Out:
# Trained_rUNet_pytorch_6positions_dataset_180epochs_0.4coeff_mask.pkl
# Checkpoint loaded
# HBox(children=(IntProgress(value=0, description='Batch', max=7, style=ProgressStyle(description_width='initial…
# batch 1
# 1: pred_dist: [-2.5473216]
# 2: pred_dist: [-3.2868924]
# 3: pred_dist: [-3.8913455]
# 4: pred_dist: [-4.5399547]
# batch 2
# 1: pred_dist: [-5.2759895]
# 2: pred_dist: [-4.5190754]
# 3: pred_dist: [-5.764985]
# 4: pred_dist: [-4.7796636]

# %% [markdown]
# ---

# %%
np.argmin(history['val_dice'])
# Out:
# 179

# %% [markdown]
# #### Check training performance

# %%
history_100 = np.load('/storage/yw18581/src/leaf_reco/saved_models/trained_6positions_multi_loss/history_Trained_rUNet_pytorch_100epochs_0.4coef.pkl', allow_pickle=True)

# %%
history_100.keys()
# Out:
# dict_keys(['train', 'val', 'train_dice', 'train_mse', 'val_dice', 'val_mse', 'epochs'])

# %%
history = np.load(os.path.join(saved_models,model_names[-1]), allow_pickle=True)

# %%
history.keys()
# Out:
# dict_keys(['train', 'val', 'train_dice', 'train_mse', 'val_dice', 'val_mse', 'epochs'])

# %%
for key in history.keys():
    plt.plot(np.hstack((history_100['epochs'],history['epochs'])), np.hstack((history_100[key],history[key])), 
             label=key)
plt.legend(loc='upper right')

# %%
for key in history.keys():
    if 'dice' in key:
        plt.plot(np.hstack((history_100['epochs'],history['epochs'])), np.hstack((history_100[key],history[key])), 
             label=key)
plt.legend(loc='upper right')
#plt.ylim(-0.002,0)
