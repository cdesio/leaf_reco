# %%
import numpy as np

# %%
import pandas as pd

# %%
resuts = np.load("/storage/yw18581/data/test_rf_1234.npz")["db"]

# %%
df = pd.DataFrame.from_records(resuts, columns=["rf","est","depth","mse"])

# %%
df["mse"].describe()
# Out:
# count    1000.000000
# mean        0.474457
# std         0.030156
# min         0.450165
# 25%         0.460185
# 50%         0.466876
# 75%         0.476200
# max         0.653333
# Name: mse, dtype: float64

# %%
df[df["mse"]==0.45016467]
# Out:
# Empty DataFrame
# Columns: [rf, est, depth, mse]
# Index: []

# %%
df['mse'].df
# Out:
# array([0.65333333, 0.65333333, 0.65333333, 0.65333333, 0.65333333,
#        0.65333333, 0.65333333, 0.65333333, 0.65333333, 0.65333333,
#        0.65333333, 0.65333333, 0.65333333, 0.65333333, 0.65333333,
#        0.65333333, 0.65333333, 0.65333333, 0.65333333, 0.65333333,
#        0.55145833, 0.55145833, 0.55145833, 0.55145833, 0.55145833,
#        0.55145833, 0.55145833, 0.55145833, 0.55145833, 0.55145833,
#        0.55145833, 0.55145833, 0.55145833, 0.55145833, 0.55145833,
#        0.55145833, 0.55145833, 0.55145833, 0.55145833, 0.55145833,
#        0.46018519, 0.46018519, 0.46018519, 0.46018519, 0.46018519,
#        0.46018519, 0.46018519, 0.46018519, 0.46018519, 0.46018519,
#        0.46018519, 0.46018519, 0.46018519, 0.46018519, 0.46018519,
#        0.46018519, 0.46018519, 0.46018519, 0.46018519, 0.46018519,
#        0.45552083, 0.45552083, 0.45552083, 0.45552083, 0.45552083,
#        0.45552083, 0.45552083, 0.45552083, 0.45552083, 0.45552083,
# ...
